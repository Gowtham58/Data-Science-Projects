# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

f=pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/Billionaire.csv")
f.head()
# Out:
#                        Name NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos   $177 B  United States         Amazon     1
# 1                 Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family   $150 B         France           LVMH     3
# 3                Bill Gates   $124 B  United States      Microsoft     4
# 4           Mark Zuckerberg    $97 B  United States       Facebook     5
#
#     Age          Industry
# 0  57.0        Technology
# 1  49.0        Automotive
# 2  72.0  Fashion & Retail
# 3  65.0        Technology
# 4  36.0        Technology

# %%
f.isna().sum()
# Out:
# Name         0
# NetWorth     0
# Country      0
# Source       0
# Rank         0
# Age         79
# Industry     0
# dtype: int64

# %%
f.dropna()
# Out:
#                           Name NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos   $177 B  United States         Amazon     1
# 1                    Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family   $150 B         France           LVMH     3
# 3                   Bill Gates   $124 B  United States      Microsoft     4
# 4              Mark Zuckerberg    $97 B  United States       Facebook     5
# ...                        ...      ...            ...            ...   ...
# 2750         Daniel Yong Zhang     $1 B          China     e-commerce  2674
# 2751             Zhang Yuqiang     $1 B          China     Fiberglass  2674
# 2752             Zhao Meiguang     $1 B          China    gold mining  2674
# 2753            Zhong Naixiong     $1 B          China   conglomerate  2674
# 2754           Zhou Wei family     $1 B          China       Software  2674
#
#        Age          Industry
# ...

# %%
f['NetWorth']=f['NetWorth'].str.strip('$')
f['NetWorth']=f['NetWorth'].str.strip('B')
f['NetWorth']=f['NetWorth'].astype(float)

# %%
f['NetWorth']
# Out:
# 0       177.0
# 1       151.0
# 2       150.0
# 3       124.0
# 4        97.0
#         ...
# 2750      1.0
# 2751      1.0
# 2752      1.0
# 2753      1.0
# 2754      1.0
# Name: NetWorth, Length: 2755, dtype: float64

# %%
df=f.sort_values(by=['NetWorth'],ascending=False).head(10)
plt.figure(figsize=(20,10))
sns.histplot(x="Name",hue="NetWorth",data=df)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Count'>

# %%
a=f['Industry'].value_counts().head()
index=[i+"("+str(j)+")" for i,j in zip(a.index,a.values)]
industries=a.values
plt.figure(figsize=(5,5))
plt.pie(industries,labels=index)
central_circle=plt.Circle((0,0),0.5,color='white')
fig=plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font',size=12)
plt.title("Top 5 Industries with most number of Billionaires",size=20)
# Out:
# Text(0.5, 1.0, 'Top 5 Industries with most number of Billionaires')

# %%
a=f['Country'].value_counts(5).head()
index=a.index
country=a.values
plt.figure(figsize=(5,5))
plt.pie(country,labels=index)
central_circle=plt.Circle((0,0),0.5,color='white')
fig=plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font',size=12)
plt.title("Top 5 Countries with most number of Billionaires",size=20)
# Out:
# Text(0.5, 1.0, 'Top 5 Countries with most number of Billionaires')

# %%
a=f['Source'].value_counts().head()
index=[i+"("+str(j)+")" for i,j in zip(a.index,a.values)]
domains=a.values
plt.figure(figsize=(5,5))
plt.pie(industries,labels=index)
central_circle=plt.Circle((0,0),0.5,color='white')
fig=plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font',size=12)
plt.title("Top 5 Domains with most number of Billionaires",size=20)
# Out:
# Text(0.5, 1.0, 'Top 5 Domains with most number of Billionaires')
