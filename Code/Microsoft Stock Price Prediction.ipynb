# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.style.use('fivethirtyeight')

data=pd.read_csv('dataset/MSFT.csv')
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2021-07-20  278.029999  280.970001  276.260010  279.320007  277.057648
# 1  2021-07-21  278.899994  281.519989  277.290009  281.399994  279.120789
# 2  2021-07-22  283.839996  286.420013  283.420013  286.140015  283.822449
# 3  2021-07-23  287.369995  289.989990  286.500000  289.670013  287.323853
# 4  2021-07-26  289.000000  289.690002  286.640015  289.049988  286.708832
#
#      Volume
# 0  26259700
# 1  24364300
# 2  23384100
# 3  22768100
# 4  23176100

# %%
plt.figure("Microsoft stock prices")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data['Close'])

# %%
print(data.corr())
sns.heatmap(data.corr())
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.994420  0.992057  0.982702   0.982259 -0.097253
# High       0.994420  1.000000  0.991444  0.991359   0.991565 -0.064853
# Low        0.992057  0.991444  1.000000  0.992278   0.991317 -0.161569
# Close      0.982702  0.991359  0.992278  1.000000   0.999706 -0.119378
# Adj Close  0.982259  0.991565  0.991317  0.999706   1.000000 -0.113634
# Volume    -0.097253 -0.064853 -0.161569 -0.119378  -0.113634  1.000000
# <AxesSubplot:>

# %%
x=data[['Open','High','Low']]
y=data['Close']
x=x.to_numpy()
y=y.to_numpy()
y=y.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain,ytrain)
ypred = model.predict(xtest)
data=pd.DataFrame(data={"Predicted Rate" : ypred})
print(data.head())
# Out:
#    Predicted Rate
# 0      285.299988
# 1      286.359985
# 2      339.119995
# 3      302.750000
# 4      339.510010
